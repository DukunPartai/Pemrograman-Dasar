# %% [markdown]
# <a href="https://colab.research.google.com/github/DukunPartai/Pemrograman-Dasar/blob/main/TUGAS_PERTEMUAN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tugas pertemuan 2

#latihan 1
tegangan_panel_surya = "18volt"
arus_panel_surya = "6ampere"
jenis_sel_panel_surya = "monocrystalline"

print ((tegangan_panel_surya),(arus_panel_surya),(jenis_sel_panel_surya))
# Out:
# 18volt 6ampere monocrystalline

# %%
#latihan 2
kubikel_20Kv = 'Feeder_Hang_Jebat'
ampere = '2500'
beban = 2.4
kondisi_saat_ini = 'BEROPERASI'

print ((kubikel_20Kv),(ampere),(beban),(kondisi_saat_ini))
# Out:
# Feeder_Hang_Jebat 2500 2.4 BEROPERASI

# %%
#latihan 3


nama_unit = "PLTS_Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = "true"

print(type(nama_unit), type(jumlah_panel), type(tegangan_keluaran), type(sedang_beroperasi))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'str'>

# %%
#latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216]
tegangan_harian.append(222.0)


len(tegangan_harian)
# Out:
# 7

# %%
#latihan 5

spesifikasi_motor_listrik = {"nama":"citrone", "daya_kW":5000, "tegangan_V":380, "rpm":300}

print(spesifikasi_motor_listrik["rpm"])
spesifikasi_motor_listrik["rpm"] = 250

print (spesifikasi_motor_listrik)
# Out:
# 300
# {'nama': 'citrone', 'daya_kW': 5000, 'tegangan_V': 380, 'rpm': 250}

# %%
#latihan 6

pembangkit = [{"nama_unit1": "pltu_kasam", "kapasitas_mW": 15, "status": "operasi"},{"nama_unit2": "pltmg_panaran", "kapasitas_mW": 20, "status": "operasi"},{"nama_unit3": "pltd_sekupang", "kapasitas_mW": 5, "status": "pemeliharaan"},]

print (pembangkit[1]["nama_unit2"])
pembangkit[2]["status"] = "operasi"
pembangkit.append ({'nama_unit4': "mitra_energi_batam", "kapasitas_mW": 25, "status": "operasi"})

print (pembangkit)
# Out:
# pltmg_panaran
# [{'nama_unit1': 'pltu_kasam', 'kapasitas_mW': 15, 'status': 'operasi'}, {'nama_unit2': 'pltmg_panaran', 'kapasitas_mW': 20, 'status': 'operasi'}, {'nama_unit3': 'pltd_sekupang', 'kapasitas_mW': 5, 'status': 'operasi'}, {'nama_unit4': 'mitra_energi_batam', 'kapasitas_mW': 25, 'status': 'operasi'}]
