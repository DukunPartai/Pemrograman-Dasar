# %% [markdown]
# <a href="https://colab.research.google.com/github/DukunPartai/Pemrograman-Dasar/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Biodata Saya

nama = "Alfredo Zizani"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemrograman Dasar'
status_lulus = False
alamat = "tiban koperasi block A6 No 21"
tempat_tanggal_lahir = "air molek 18 april 2006"
anak_ke = 4
pendidikan_terakhir = "SMKN 1 Pasir Penyu"
jurusan = "Agribisnis Pengolahan Hasil Pertanian"
alasan_kuliah_di_jurusan_teknik_elektro = "Karna memiliki lapangan kerja yg luas dan pilihan kerja yg banyak"



print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (alamat)
print (tempat_tanggal_lahir)
print (anak_ke)
print (pendidikan_terakhir)
print (jurusan)
print (alasan_kuliah_di_jurusan_teknik_elektro)
# Out:
# Alfredo Zizani
# 20
# Agribisnis Pengolahan Hasil Pertanian
# 3
# Pemrograman Dasar
# False
# tiban koperasi block A6 No 21
# air molek 18 april 2006
# 4
# SMKN 1 Pasir Penyu
# Agribisnis Pengolahan Hasil Pertanian
# Karna memiliki lapangan kerja yg luas dan pilihan kerja yg banyak
